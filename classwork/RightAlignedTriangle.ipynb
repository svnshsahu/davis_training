# %% [markdown]
# <a href="https://colab.research.google.com/github/svnshsahu/davis_training/blob/main/classwork/RightAlignedTriangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rows = 5
for i in range(1,rows+1):
  print(" "*(rows-i) , "*"*i)
# Out:
#      *
#     **
#    ***
#   ****
#  *****
