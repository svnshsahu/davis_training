# %% [markdown]
# <a href="https://colab.research.google.com/github/svnshsahu/davis_training/blob/main/classwork/EvenOddFunc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def func(x):
  if(x%2==0) :
    return "even"
  else :
    return "odd"
num = int(input ("Enter a no."))
n = func(num)
print(n)
# Out:
# Enter a no.555
# odd
