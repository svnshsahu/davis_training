# %% [markdown]
# <a href="https://colab.research.google.com/github/svnshsahu/davis_training/blob/main/classwork/WriteTwentyLines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentences = []

for i in range(20):
    s = input(f"Enter sentence {i+1}: ")
    sentences.append(s + "\n")

with open("sentences3.txt", "w") as f:
    f.writelines(sentences)

print("Done!")
