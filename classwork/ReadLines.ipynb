# %% [markdown]
# <a href="https://colab.research.google.com/github/svnshsahu/davis_training/blob/main/classwork/ReadLines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open("text1.txt")
if(f):
  data = f.readline()
  if(data):
    print("Content of File : ")
    while(data):
      print(data)
      data = f.readline()
  else:
    print("File is Empty")
  f.close()
else:
  print("File Not Found")
