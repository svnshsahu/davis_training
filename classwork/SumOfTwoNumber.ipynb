# %% [markdown]
# <a href="https://colab.research.google.com/github/svnshsahu/davis_training/blob/main/classwork/SumOfTwoNumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sum(x , y):
  return x+y
a = int(input("Enter first number "))
b= int(input("Enter second number "))

add = sum(a,b)

print("Sum of " , a , "and " , b , "is " , add   )
# Out:
# Enter first number 10
# Enter second number 20
# Sum of  10 and  20 is  30
