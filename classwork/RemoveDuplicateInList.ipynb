# %% [markdown]
# <a href="https://colab.research.google.com/github/svnshsahu/davis_training/blob/main/classwork/RemoveDuplicateInList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mylist = []
result = []
myset = set()
for i in range(0,15):
  x=int(input("Enter any number : "))
  mylist.append(x)

for item in mylist:
  if item not in myset:
    myset.add(item);
    result.append(item)
print(result)
# Out:
# Enter any number : 1
# Enter any number : 2
# Enter any number : 99
# Enter any number : 11
# Enter any number : 22
# Enter any number : 99
# Enter any number : 11
# Enter any number : 45
# Enter any number : 56
# Enter any number : 56
# Enter any number : 10
# Enter any number : 1
# Enter any number : 5
# Enter any number : 6
# Enter any number : 9
# [1, 2, 99, 11, 22, 45, 56, 10, 5, 6, 9]
