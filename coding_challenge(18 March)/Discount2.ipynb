# %% [markdown]
# <a href="https://colab.research.google.com/github/svnshsahu/davis_training/blob/main/coding_challenge(18%20March)/Discount2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def discount(price, discount):
    return price - (price * discount / 100)
price = int(input("Enter Price"))
discount = int(input("Enter Discount"))
print(discount(price, discount))
