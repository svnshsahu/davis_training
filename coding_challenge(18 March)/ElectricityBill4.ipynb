# %% [markdown]
# <a href="https://colab.research.google.com/github/svnshsahu/davis_training/blob/main/coding_challenge(18%20March)/ElectricityBill4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
u=int(input("Enter Unit"))
bill = u*1.5 if u<=100 else (100*1.5+(u-100)*2.5 if u<=200 else 100*1.5+100*2.5+(u-200)*4)
print(bill)
