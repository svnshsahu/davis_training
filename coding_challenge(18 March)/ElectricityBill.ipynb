# %% [markdown]
# <a href="https://colab.research.google.com/github/svnshsahu/davis_training/blob/main/coding_challenge(18%20March)/ElectricityBill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Unit = int(input("Enter the unit: "))
print("Charge Per Unit = 100")
print("Total Charge = " ,Unit*100)
