# %% [markdown]
# <a href="https://colab.research.google.com/github/svnshsahu/davis_training/blob/main/coding_challenge(18%20March)/Discount3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p=float(input());
d=float(input())
print(p - p*d/100)
