# %% [markdown]
# <a href="https://colab.research.google.com/github/svnshsahu/davis_training/blob/main/coding_challenge(18%20March)/Discount1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = int(input("Enter price"))
discount = int(input("Enter discount percentage"))
answer = price - (price * discount / 100)
print(answer)
